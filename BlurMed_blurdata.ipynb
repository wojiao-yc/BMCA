# %%
import os
os.environ['http_proxy'] = 'http://127.0.0.1:7896'
os.environ['https_proxy'] = 'http://127.0.0.1:7896'
os.environ['all_proxy'] = 'socks5://127.0.0.1:7897'

from typing import Iterable, List, Optional, Tuple
import open_clip
import argparse
import math
import torch
import random
import itertools
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW
from torch.utils.data import DataLoader
from PIL import Image
from transformers import CLIPVisionModel
from data_preparing.blureegdatasets import EEGDataset
from model.EEG_MedformerTS_refined import eeg_encoder
from model.eeg_encoder import build_eeg_encoder
# from model.EEG_MedformerTS import eeg_encoder
# from model.custom_pipeline import *

# %%
def train_one_step(text_features_all, img_features_all, dataloader, optimizer=None, device=None, model=None):
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    if model is None:
        model = eeg_encoder()


    model.to(device)
    model.train()
    text_features_all = text_features_all.to(device).float()
    img_features_all = (img_features_all[::10]).to(device).float()

    total_loss = 0
    correct = 0
    total = 0
    features_list = []

    for batch_idx, (eeg_data, labels, text, text_features, img, img_features) in enumerate(dataloader):
        eeg_data = eeg_data.to(device)
        text_features = text_features.to(device).float()
        img_features = img_features.to(device).float()
        labels = labels.to(device)

        optimizer.zero_grad()
        batch_size = eeg_data.size(0)

        eeg_features = model(eeg_data)
        features_list.append(eeg_features)
        logit_scale = model.logit_scale

        eeg_alignment_loss = model.loss_func(img_features, eeg_features, logit_scale)
        # eeg_alignment_loss = model.loss_func(img_features, eeg_features, logit_scale)
        loss = eeg_alignment_loss
        # loss =  eeg_alignment_loss

        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        logits_img = logit_scale * eeg_features @ img_features_all.T
        logits_single = logits_img
        predicted = torch.argmax(logits_single, dim=1)

        batch_size = predicted.shape[0]
        total += batch_size
        correct += (predicted == labels).sum().item()

        del eeg_data, labels, text, text_features, img, img_features

    average_loss = total_loss / (batch_idx + 1)
    accuracy = correct / total
    return average_loss, accuracy, torch.cat(features_list, dim=0)

# %%
def evaluate_model(text_features_all, img_features_all, dataloader, optimizer=None, device=None, model=None, k=None):
    """Evaluation function with k-way classification."""
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    if model is None:
        model = eeg_encoder().to(device)

    if optimizer is None:
        optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4)

    model.eval()
    text_features_all = text_features_all.to(device).float()
    img_features_all = img_features_all.to(device).float()

    total_loss = 0
    correct = 0
    total = 0
    alpha = 0.3
    top5_correct_count = 0
    all_labels = set(range(text_features_all.size(0)))

    with torch.no_grad():
        for batch_idx, (eeg_data, labels, text, text_features, img, img_features) in enumerate(dataloader):
            eeg_data = eeg_data.to(device)
            text_features = text_features.to(device).float()
            labels = labels.to(device)
            img_features = img_features.to(device).float()

            eeg_features = model(eeg_data)
            logit_scale = model.logit_scale

            eeg_alignment_loss = model.loss_func(eeg_features, eeg_features, logit_scale)
            loss = eeg_alignment_loss
            total_loss += loss.item()

            for idx, label in enumerate(labels):
                possible_classes = list(all_labels - {label.item()})
                selected_classes = random.sample(possible_classes, k - 1) + [label.item()]
                selected_img_features = img_features_all[selected_classes]
                # selected_attended_img_features_all = attended_img_features_all[selected_classes]

                logits_img = logit_scale * eeg_features[idx] @ selected_img_features.T
                logits_single = logits_img
                predicted_label = selected_classes[torch.argmax(logits_single).item()]

                if predicted_label == label.item():
                    correct += 1

                if k in [50, 100, 200]:
                    _, top5_indices = torch.topk(logits_single, 5, largest=True)
                    if label.item() in [selected_classes[i] for i in top5_indices.tolist()]:
                        top5_correct_count += 1
                total += 1

    average_loss = total_loss / (batch_idx + 1)
    accuracy = correct / total
    top5_acc = top5_correct_count / total if k in [50, 100, 200] else 0
    return average_loss, accuracy, top5_acc

# %%
def main_train_loop(epochs, model, train_dataloader, test_dataloader, optimizer, device, text_features_train_all, text_features_test_all, img_features_train_all, img_features_test_all):

    if optimizer is None:
        optimizer = AdamW(itertools.chain(model.parameters()), lr=3e-4)

    for epoch in range(epochs):
        train_loss, train_accuracy, features_tensor = train_one_step(
            text_features_train_all,
            img_features_train_all,
            train_dataloader,
            optimizer,
            device,
            model,
        )

        test_loss, test_accuracy, top5_acc = evaluate_model(
            text_features_test_all,
            img_features_test_all,
            test_dataloader,
            optimizer,
            device,
            model,
            k=200,
        )
        _, v2_acc, _ = evaluate_model(
            text_features_test_all,
            img_features_test_all,
            test_dataloader,
            optimizer,
            device,
            model,
            k=2,
        )
        _, v4_acc, _ = evaluate_model(
            text_features_test_all,
            img_features_test_all,
            test_dataloader,
            optimizer,
            device,
            model,
            k=4,
        )
        _, v10_acc, _ = evaluate_model(
            text_features_test_all,
            img_features_test_all,
            test_dataloader,
            optimizer,
            device,
            model,
            k=10,
        )
        _, v50_acc, v50_top5_acc = evaluate_model(
            text_features_test_all,
            img_features_test_all,
            test_dataloader,
            optimizer,
            device,
            model,
            k=50,
        )
        _, v100_acc, v100_top5_acc = evaluate_model(
            text_features_test_all,
            img_features_test_all,
            test_dataloader,
            optimizer,
            device,
            model,
            k=100,
        )

        print(
            f"Epoch {epoch + 1}/{epochs} - "
            f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, "
            f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}, "
            f"Top5 Accuracy: {top5_acc:.4f}"
        )

        print(
            f"Epoch {epoch + 1}/{epochs} - "
            f"v2 Accuracy: {v2_acc:.4f} - v4 Accuracy: {v4_acc:.4f} - "
            f"v10 Accuracy: {v10_acc:.4f} - v50 Accuracy: {v50_acc:.4f} - "
            f"v100 Accuracy: {v100_acc:.4f}"
        )

# %%
def main():
    """Main function to parse arguments and run training."""
    data_path = '/mnt/dataset0/ldy/datasets/THINGS_EEG/Preprocessed_data_250Hz'
    lr = 1e-4
    epochs = 50
    batch_size = 128
    sub = 'sub-02'
    subjects = [f'sub-{i:02d}' for i in range(1, 11)]

    device = torch.device('cuda:5' if torch.cuda.is_available() else 'cpu')
    train_dataset = EEGDataset(data_path, adap_subject=sub, subjects=[sub], train=True)
    test_dataset = EEGDataset(data_path, adap_subject=sub, subjects=[sub], train=False)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
    test_loader = DataLoader(test_dataset, batch_size=1, shuffle=True, drop_last=True)

    text_features_train_all = train_dataset.text_features
    text_features_test_all = test_dataset.text_features
    img_features_train_all = train_dataset.img_features
    img_features_test_all = test_dataset.img_features

    feature_dim = img_features_train_all.shape[-1]

    model = build_eeg_encoder(
        "EEGProjectLayer",
        z_dim=1024,
        c_num=63,
        timesteps=(0, 250)
    )

    # model = eeg_encoder()
    optimizer = AdamW(itertools.chain(model.parameters()), lr=lr)

    results = main_train_loop(
        epochs,
        model,
        train_loader,
        test_loader,
        optimizer,
        device,
        text_features_train_all,
        text_features_test_all,
        img_features_train_all,
        img_features_test_all,
    )

# %%
main()
# Out:
# self.subjects ['sub-02']
# adap_subject sub-02
# data_tensor torch.Size([66160, 63, 250])
# Data tensor shape: torch.Size([66160, 63, 250]), label tensor shape: torch.Size([66160]), text length: 1654, image length: 16540
# Text features shape: torch.Size([1654, 1024])
# Image features shape: torch.Size([16540, 1024])
# self.subjects ['sub-02']
# adap_subject sub-02
# Data tensor shape: torch.Size([200, 63, 250]), label tensor shape: torch.Size([200]), text length: 200, image length: 200
# Text features shape: torch.Size([200, 1024])
# Image features shape: torch.Size([200, 1024])
# Epoch 1/50 - Train Loss: 5.0639, Train Accuracy: 0.0014, Test Loss: 0.0000, Test Accuracy: 0.0500, Top5 Accuracy: 0.2100
# Epoch 1/50 - v2 Accuracy: 0.8700 - v4 Accuracy: 0.7150 - v10 Accuracy: 0.4600 - v50 Accuracy: 0.1800 - v100 Accuracy: 0.0850
# Epoch 2/50 - Train Loss: 3.9613, Train Accuracy: 0.0071, Test Loss: 0.0000, Test Accuracy: 0.1400, Top5 Accuracy: 0.3850
# Epoch 2/50 - v2 Accuracy: 0.9050 - v4 Accuracy: 0.7800 - v10 Accuracy: 0.6050 - v50 Accuracy: 0.3350 - v100 Accuracy: 0.2250
# Epoch 3/50 - Train Loss: 3.1401, Train Accuracy: 0.0178, Test Loss: 0.0000, Test Accuracy: 0.2100, Top5 Accuracy: 0.4650
# Epoch 3/50 - v2 Accuracy: 0.9350 - v4 Accuracy: 0.8350 - v10 Accuracy: 0.7150 - v50 Accuracy: 0.3850 - v100 Accuracy: 0.2500
# Epoch 4/50 - Train Loss: 2.3109, Train Accuracy: 0.0356, Test Loss: 0.0000, Test Accuracy: 0.2750, Top5 Accuracy: 0.5450
# Epoch 4/50 - v2 Accuracy: 0.9600 - v4 Accuracy: 0.8900 - v10 Accuracy: 0.7800 - v50 Accuracy: 0.4300 - v100 Accuracy: 0.3250
# Epoch 5/50 - Train Loss: 1.6300, Train Accuracy: 0.0564, Test Loss: 0.0000, Test Accuracy: 0.2700, Top5 Accuracy: 0.6150
# Epoch 5/50 - v2 Accuracy: 0.9450 - v4 Accuracy: 0.9250 - v10 Accuracy: 0.8000 - v50 Accuracy: 0.4800 - v100 Accuracy: 0.3800
# Epoch 6/50 - Train Loss: 1.1161, Train Accuracy: 0.0756, Test Loss: 0.0000, Test Accuracy: 0.3100, Top5 Accuracy: 0.6800
# Epoch 6/50 - v2 Accuracy: 0.9650 - v4 Accuracy: 0.9050 - v10 Accuracy: 0.7850 - v50 Accuracy: 0.5800 - v100 Accuracy: 0.4350
# Epoch 7/50 - Train Loss: 0.7618, Train Accuracy: 0.0946, Test Loss: 0.0000, Test Accuracy: 0.3000, Top5 Accuracy: 0.6650
# Epoch 7/50 - v2 Accuracy: 0.9700 - v4 Accuracy: 0.8800 - v10 Accuracy: 0.7900 - v50 Accuracy: 0.5250 - v100 Accuracy: 0.4100
# Epoch 8/50 - Train Loss: 0.5227, Train Accuracy: 0.1127, Test Loss: 0.0000, Test Accuracy: 0.3050, Top5 Accuracy: 0.6250
# Epoch 8/50 - v2 Accuracy: 0.9700 - v4 Accuracy: 0.9100 - v10 Accuracy: 0.8200 - v50 Accuracy: 0.5300 - v100 Accuracy: 0.4000
# Epoch 9/50 - Train Loss: 0.3704, Train Accuracy: 0.1243, Test Loss: 0.0000, Test Accuracy: 0.3450, Top5 Accuracy: 0.7100
# Epoch 9/50 - v2 Accuracy: 0.9750 - v4 Accuracy: 0.9150 - v10 Accuracy: 0.8500 - v50 Accuracy: 0.5100 - v100 Accuracy: 0.4500
# Epoch 10/50 - Train Loss: 0.2799, Train Accuracy: 0.1324, Test Loss: 0.0000, Test Accuracy: 0.3400, Top5 Accuracy: 0.6400
# Epoch 10/50 - v2 Accuracy: 0.9800 - v4 Accuracy: 0.9300 - v10 Accuracy: 0.8200 - v50 Accuracy: 0.5400 - v100 Accuracy: 0.4200
# Epoch 11/50 - Train Loss: 0.2381, Train Accuracy: 0.1366, Test Loss: 0.0000, Test Accuracy: 0.3500, Top5 Accuracy: 0.6950
# Epoch 11/50 - v2 Accuracy: 0.9650 - v4 Accuracy: 0.9200 - v10 Accuracy: 0.8300 - v50 Accuracy: 0.5700 - v100 Accuracy: 0.4700
# Epoch 12/50 - Train Loss: 0.2079, Train Accuracy: 0.1418, Test Loss: 0.0000, Test Accuracy: 0.3450, Top5 Accuracy: 0.7000
# Epoch 12/50 - v2 Accuracy: 0.9650 - v4 Accuracy: 0.9550 - v10 Accuracy: 0.7950 - v50 Accuracy: 0.5900 - v100 Accuracy: 0.4450
# Epoch 13/50 - Train Loss: 0.1894, Train Accuracy: 0.1424, Test Loss: 0.0000, Test Accuracy: 0.2950, Top5 Accuracy: 0.6250
# Epoch 13/50 - v2 Accuracy: 0.9750 - v4 Accuracy: 0.9100 - v10 Accuracy: 0.8300 - v50 Accuracy: 0.5200 - v100 Accuracy: 0.4300
# Epoch 14/50 - Train Loss: 0.1830, Train Accuracy: 0.1444, Test Loss: 0.0000, Test Accuracy: 0.3450, Top5 Accuracy: 0.6450
# Epoch 14/50 - v2 Accuracy: 0.9600 - v4 Accuracy: 0.8850 - v10 Accuracy: 0.8400 - v50 Accuracy: 0.5700 - v100 Accuracy: 0.4650
# Epoch 15/50 - Train Loss: 0.1597, Train Accuracy: 0.1472, Test Loss: 0.0000, Test Accuracy: 0.3100, Top5 Accuracy: 0.6700
# Epoch 15/50 - v2 Accuracy: 0.9650 - v4 Accuracy: 0.9200 - v10 Accuracy: 0.8350 - v50 Accuracy: 0.5200 - v100 Accuracy: 0.4200
# Epoch 16/50 - Train Loss: 0.1554, Train Accuracy: 0.1486, Test Loss: 0.0000, Test Accuracy: 0.3250, Top5 Accuracy: 0.6350
# Epoch 16/50 - v2 Accuracy: 0.9450 - v4 Accuracy: 0.9100 - v10 Accuracy: 0.7850 - v50 Accuracy: 0.5050 - v100 Accuracy: 0.4400
# Epoch 17/50 - Train Loss: 0.1338, Train Accuracy: 0.1511, Test Loss: 0.0000, Test Accuracy: 0.3200, Top5 Accuracy: 0.6350
# Epoch 17/50 - v2 Accuracy: 0.9650 - v4 Accuracy: 0.9000 - v10 Accuracy: 0.8100 - v50 Accuracy: 0.5100 - v100 Accuracy: 0.4250
# Epoch 18/50 - Train Loss: 0.1274, Train Accuracy: 0.1523, Test Loss: 0.0000, Test Accuracy: 0.3100, Top5 Accuracy: 0.6200
# Epoch 18/50 - v2 Accuracy: 0.9500 - v4 Accuracy: 0.8900 - v10 Accuracy: 0.8100 - v50 Accuracy: 0.4800 - v100 Accuracy: 0.4000
# Epoch 19/50 - Train Loss: 0.1224, Train Accuracy: 0.1521, Test Loss: 0.0000, Test Accuracy: 0.3250, Top5 Accuracy: 0.6750
# Epoch 19/50 - v2 Accuracy: 0.9450 - v4 Accuracy: 0.9100 - v10 Accuracy: 0.7750 - v50 Accuracy: 0.5650 - v100 Accuracy: 0.4250
# Epoch 20/50 - Train Loss: 0.1141, Train Accuracy: 0.1532, Test Loss: 0.0000, Test Accuracy: 0.3250, Top5 Accuracy: 0.6550
# Epoch 20/50 - v2 Accuracy: 0.9550 - v4 Accuracy: 0.9200 - v10 Accuracy: 0.8150 - v50 Accuracy: 0.5200 - v100 Accuracy: 0.3950
# Epoch 21/50 - Train Loss: 0.1075, Train Accuracy: 0.1566, Test Loss: 0.0000, Test Accuracy: 0.3000, Top5 Accuracy: 0.6300
# Epoch 21/50 - v2 Accuracy: 0.9550 - v4 Accuracy: 0.9100 - v10 Accuracy: 0.7800 - v50 Accuracy: 0.5050 - v100 Accuracy: 0.4100
# Epoch 22/50 - Train Loss: 0.1111, Train Accuracy: 0.1546, Test Loss: 0.0000, Test Accuracy: 0.3050, Top5 Accuracy: 0.6600
# Epoch 22/50 - v2 Accuracy: 0.9600 - v4 Accuracy: 0.8900 - v10 Accuracy: 0.7700 - v50 Accuracy: 0.5150 - v100 Accuracy: 0.4150
# Epoch 23/50 - Train Loss: 0.0956, Train Accuracy: 0.1582, Test Loss: 0.0000, Test Accuracy: 0.3050, Top5 Accuracy: 0.6600
# Epoch 23/50 - v2 Accuracy: 0.9600 - v4 Accuracy: 0.8950 - v10 Accuracy: 0.7900 - v50 Accuracy: 0.5200 - v100 Accuracy: 0.4100
# Epoch 24/50 - Train Loss: 0.0971, Train Accuracy: 0.1566, Test Loss: 0.0000, Test Accuracy: 0.2950, Top5 Accuracy: 0.6050
# Epoch 24/50 - v2 Accuracy: 0.9550 - v4 Accuracy: 0.9050 - v10 Accuracy: 0.7700 - v50 Accuracy: 0.4650 - v100 Accuracy: 0.3900
# Epoch 25/50 - Train Loss: 0.0959, Train Accuracy: 0.1574, Test Loss: 0.0000, Test Accuracy: 0.2550, Top5 Accuracy: 0.6100
# Epoch 25/50 - v2 Accuracy: 0.9400 - v4 Accuracy: 0.9200 - v10 Accuracy: 0.7350 - v50 Accuracy: 0.5050 - v100 Accuracy: 0.3650
# Epoch 26/50 - Train Loss: 0.0917, Train Accuracy: 0.1570, Test Loss: 0.0000, Test Accuracy: 0.2850, Top5 Accuracy: 0.6050
# Epoch 26/50 - v2 Accuracy: 0.9800 - v4 Accuracy: 0.9000 - v10 Accuracy: 0.7800 - v50 Accuracy: 0.4900 - v100 Accuracy: 0.4000
# Epoch 27/50 - Train Loss: 0.0887, Train Accuracy: 0.1570, Test Loss: 0.0000, Test Accuracy: 0.3250, Top5 Accuracy: 0.6050
# Epoch 27/50 - v2 Accuracy: 0.9650 - v4 Accuracy: 0.8650 - v10 Accuracy: 0.7900 - v50 Accuracy: 0.5200 - v100 Accuracy: 0.4200
# Epoch 28/50 - Train Loss: 0.0801, Train Accuracy: 0.1599, Test Loss: 0.0000, Test Accuracy: 0.3050, Top5 Accuracy: 0.5800
# Epoch 28/50 - v2 Accuracy: 0.9400 - v4 Accuracy: 0.8750 - v10 Accuracy: 0.8100 - v50 Accuracy: 0.5200 - v100 Accuracy: 0.3500
# Epoch 29/50 - Train Loss: 0.0754, Train Accuracy: 0.1598, Test Loss: 0.0000, Test Accuracy: 0.2650, Top5 Accuracy: 0.5900
# Epoch 29/50 - v2 Accuracy: 0.9600 - v4 Accuracy: 0.8950 - v10 Accuracy: 0.7500 - v50 Accuracy: 0.4650 - v100 Accuracy: 0.3750
# Epoch 30/50 - Train Loss: 0.0767, Train Accuracy: 0.1595, Test Loss: 0.0000, Test Accuracy: 0.2700, Top5 Accuracy: 0.5700
# Epoch 30/50 - v2 Accuracy: 0.9550 - v4 Accuracy: 0.8850 - v10 Accuracy: 0.7500 - v50 Accuracy: 0.5150 - v100 Accuracy: 0.3700
# Epoch 31/50 - Train Loss: 0.0799, Train Accuracy: 0.1578, Test Loss: 0.0000, Test Accuracy: 0.3000, Top5 Accuracy: 0.5650
# Epoch 31/50 - v2 Accuracy: 0.9600 - v4 Accuracy: 0.8700 - v10 Accuracy: 0.7450 - v50 Accuracy: 0.4800 - v100 Accuracy: 0.3850
# Epoch 32/50 - Train Loss: 0.0744, Train Accuracy: 0.1591, Test Loss: 0.0000, Test Accuracy: 0.2450, Top5 Accuracy: 0.6000
# Epoch 32/50 - v2 Accuracy: 0.9600 - v4 Accuracy: 0.9250 - v10 Accuracy: 0.7900 - v50 Accuracy: 0.5150 - v100 Accuracy: 0.3900
# Epoch 33/50 - Train Loss: 0.0721, Train Accuracy: 0.1606, Test Loss: 0.0000, Test Accuracy: 0.3150, Top5 Accuracy: 0.6350
# Epoch 33/50 - v2 Accuracy: 0.9500 - v4 Accuracy: 0.9250 - v10 Accuracy: 0.7650 - v50 Accuracy: 0.5400 - v100 Accuracy: 0.3800
# Epoch 34/50 - Train Loss: 0.0707, Train Accuracy: 0.1612, Test Loss: 0.0000, Test Accuracy: 0.2850, Top5 Accuracy: 0.6100
# Epoch 34/50 - v2 Accuracy: 0.9600 - v4 Accuracy: 0.9000 - v10 Accuracy: 0.7300 - v50 Accuracy: 0.4700 - v100 Accuracy: 0.3450
# Epoch 35/50 - Train Loss: 0.0671, Train Accuracy: 0.1593, Test Loss: 0.0000, Test Accuracy: 0.2600, Top5 Accuracy: 0.5500
# Epoch 35/50 - v2 Accuracy: 0.9900 - v4 Accuracy: 0.8900 - v10 Accuracy: 0.7550 - v50 Accuracy: 0.4350 - v100 Accuracy: 0.3200
# Epoch 36/50 - Train Loss: 0.0720, Train Accuracy: 0.1599, Test Loss: 0.0000, Test Accuracy: 0.2350, Top5 Accuracy: 0.5700
# Epoch 36/50 - v2 Accuracy: 0.9400 - v4 Accuracy: 0.8550 - v10 Accuracy: 0.7500 - v50 Accuracy: 0.4350 - v100 Accuracy: 0.3300
# Epoch 37/50 - Train Loss: 0.0653, Train Accuracy: 0.1613, Test Loss: 0.0000, Test Accuracy: 0.2700, Top5 Accuracy: 0.5700
# Epoch 37/50 - v2 Accuracy: 0.9550 - v4 Accuracy: 0.8600 - v10 Accuracy: 0.7700 - v50 Accuracy: 0.4550 - v100 Accuracy: 0.3400
# Epoch 38/50 - Train Loss: 0.0646, Train Accuracy: 0.1610, Test Loss: 0.0000, Test Accuracy: 0.2350, Top5 Accuracy: 0.5300
# Epoch 38/50 - v2 Accuracy: 0.9600 - v4 Accuracy: 0.9000 - v10 Accuracy: 0.7300 - v50 Accuracy: 0.4150 - v100 Accuracy: 0.3450
# Epoch 39/50 - Train Loss: 0.0642, Train Accuracy: 0.1611, Test Loss: 0.0000, Test Accuracy: 0.2350, Top5 Accuracy: 0.5750
# Epoch 39/50 - v2 Accuracy: 0.9550 - v4 Accuracy: 0.8700 - v10 Accuracy: 0.7800 - v50 Accuracy: 0.4600 - v100 Accuracy: 0.3100
# Epoch 40/50 - Train Loss: 0.0650, Train Accuracy: 0.1618, Test Loss: 0.0000, Test Accuracy: 0.2450, Top5 Accuracy: 0.5750
# Epoch 40/50 - v2 Accuracy: 0.9750 - v4 Accuracy: 0.8650 - v10 Accuracy: 0.7300 - v50 Accuracy: 0.4350 - v100 Accuracy: 0.2900
# Epoch 41/50 - Train Loss: 0.0641, Train Accuracy: 0.1607, Test Loss: 0.0000, Test Accuracy: 0.2300, Top5 Accuracy: 0.5800
# Epoch 41/50 - v2 Accuracy: 0.9550 - v4 Accuracy: 0.8850 - v10 Accuracy: 0.7450 - v50 Accuracy: 0.4450 - v100 Accuracy: 0.3050
# Epoch 42/50 - Train Loss: 0.0623, Train Accuracy: 0.1606, Test Loss: 0.0000, Test Accuracy: 0.2650, Top5 Accuracy: 0.5550
# Epoch 42/50 - v2 Accuracy: 0.9550 - v4 Accuracy: 0.8800 - v10 Accuracy: 0.7500 - v50 Accuracy: 0.4600 - v100 Accuracy: 0.3350
# Epoch 43/50 - Train Loss: 0.0592, Train Accuracy: 0.1621, Test Loss: 0.0000, Test Accuracy: 0.2350, Top5 Accuracy: 0.5450
# Epoch 43/50 - v2 Accuracy: 0.9050 - v4 Accuracy: 0.9050 - v10 Accuracy: 0.7350 - v50 Accuracy: 0.4400 - v100 Accuracy: 0.3400
# Epoch 44/50 - Train Loss: 0.0605, Train Accuracy: 0.1605, Test Loss: 0.0000, Test Accuracy: 0.2350, Top5 Accuracy: 0.5750
# Epoch 44/50 - v2 Accuracy: 0.9300 - v4 Accuracy: 0.8550 - v10 Accuracy: 0.7500 - v50 Accuracy: 0.4650 - v100 Accuracy: 0.3450
# Epoch 45/50 - Train Loss: 0.0573, Train Accuracy: 0.1606, Test Loss: 0.0000, Test Accuracy: 0.2650, Top5 Accuracy: 0.5650
# Epoch 45/50 - v2 Accuracy: 0.9250 - v4 Accuracy: 0.8500 - v10 Accuracy: 0.7650 - v50 Accuracy: 0.4450 - v100 Accuracy: 0.3450
# Epoch 46/50 - Train Loss: 0.0593, Train Accuracy: 0.1608, Test Loss: 0.0000, Test Accuracy: 0.2350, Top5 Accuracy: 0.5800
# Epoch 46/50 - v2 Accuracy: 0.9400 - v4 Accuracy: 0.8700 - v10 Accuracy: 0.6800 - v50 Accuracy: 0.4450 - v100 Accuracy: 0.3250
# Epoch 47/50 - Train Loss: 0.0599, Train Accuracy: 0.1604, Test Loss: 0.0000, Test Accuracy: 0.2600, Top5 Accuracy: 0.5400
# Epoch 47/50 - v2 Accuracy: 0.9400 - v4 Accuracy: 0.8450 - v10 Accuracy: 0.7600 - v50 Accuracy: 0.4600 - v100 Accuracy: 0.3250
# Epoch 48/50 - Train Loss: 0.0536, Train Accuracy: 0.1622, Test Loss: 0.0000, Test Accuracy: 0.2500, Top5 Accuracy: 0.5850
# Epoch 48/50 - v2 Accuracy: 0.9450 - v4 Accuracy: 0.8500 - v10 Accuracy: 0.7450 - v50 Accuracy: 0.4900 - v100 Accuracy: 0.3450
# Epoch 49/50 - Train Loss: 0.0531, Train Accuracy: 0.1620, Test Loss: 0.0000, Test Accuracy: 0.2550, Top5 Accuracy: 0.5850
# Epoch 49/50 - v2 Accuracy: 0.9500 - v4 Accuracy: 0.8700 - v10 Accuracy: 0.7300 - v50 Accuracy: 0.4800 - v100 Accuracy: 0.3300
# Epoch 50/50 - Train Loss: 0.0528, Train Accuracy: 0.1617, Test Loss: 0.0000, Test Accuracy: 0.2350, Top5 Accuracy: 0.5700
# Epoch 50/50 - v2 Accuracy: 0.9350 - v4 Accuracy: 0.8600 - v10 Accuracy: 0.7850 - v50 Accuracy: 0.4400 - v100 Accuracy: 0.3200

# %%
# device = "cuda" if torch.cuda.is_available() else "cpu"
# bridge_pairs = [(6, 0), (12, 1), (18, 2)]
# model = FusedEEGViT(
#     bridge_pairs=bridge_pairs,
#     n_heads_bridge=8,
#     lora_r=8,
#     med_depth=3,
#     model_type="ViT-H-14",
#     pretrained="laion2b_s32b_b79k",
# ).to(device)
# set_trainable_parameters(model)
# B = 1
# device = "cuda:0" if torch.cuda.is_available() else "cpu"
# _, _, preprocess = open_clip.create_model_and_transforms(
#     model_name="ViT-H-14",
#     pretrained="laion2b_s32b_b79k",
# )
# image_path = "/home/wenxiao/workspace/qhy/BMCA/image.png"
# image = Image.open(image_path).convert("RGB")
# pixel_values = preprocess(image).unsqueeze(0).to(device)
# # pixel_values = torch.randn(B, 3, 224, 224, device=device)
# eeg = torch.randn(B, 63, 250, device=device)
# out = model(pixel_values, eeg)
# print(out)
# for k, v in out.items():
#     if isinstance(v, torch.Tensor):
#         print(k, tuple(v.shape))
#     else:
#         print(k, v)



# device = "cuda:0" if torch.cuda.is_available() else "cpu"

# generator = Generator4Embeds()
# z_pure = out["z_pure"]  # Tensor
# z_pure = z_pure / z_pure.norm(dim=-1, keepdim=True)  # 归一化
# z_pure = z_pure.unsqueeze(0)

# # 需要确保 device/dtype 与 generator 的一致
# z_pure = z_pure.to(device=device, dtype=generator.dtype)

# # 如果 batch_size=1，则取第一个即可
# if z_pure.dim() == 4:   # (B, C, H, W)
#     z_pure = z_pure[0]

# # 生成图像
# image = generator.generate(
#     image_embeds=z_pure, 
#     text_prompt="", 
#     generator=None
# )

# # 保存或显示图像
# image.save("generated.png")
